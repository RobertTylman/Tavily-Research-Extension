# %% [markdown]
# # Multi-Provider Evaluation Overview
#
# This notebook reads normalized fact-check artifacts from `../results/live/`, computes summary tables, and visualizes provider quality, latency, and error patterns.

# %%
from pathlib import Path
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style='whitegrid', context='talk')
RESULTS_DIR = Path('../results/live')
SUMMARY_DIR = RESULTS_DIR / 'summary'
SUMMARY_DIR.mkdir(parents=True, exist_ok=True)

# %%
def load_artifacts(results_dir: Path) -> pd.DataFrame:
    rows = []
    for path in sorted(results_dir.rglob('*.json')):
        if 'summary' in path.parts:
            continue
        payload = json.loads(path.read_text())
        if isinstance(payload, list):
            rows.extend(payload)
        else:
            rows.append(payload)
    return pd.DataFrame(rows)

raw = load_artifacts(RESULTS_DIR)
raw.head(2)
# Out:
#                                                   id  \
# 0  benchmark_20260502T184021Z_claim_moon_01_tavil...
# 1  benchmark_20260502T184021Z_claim_moon_01_exa_e...
#
#                           timestamp  \
# 0  2026-05-02T18:40:34.151685+00:00
# 1  2026-05-02T18:40:34.353388+00:00
#
#                                                claim provider  \
# 0  {'id': 'claim_moon_01', 'text': 'The Moon land...   tavily
# 1  {'id': 'claim_moon_01', 'text': 'The Moon land...      exa
#
#            provider_mode                         research_endpoint  \
# 0        tavily_research  POST/GET https://api.tavily.com/research
# 1  exa_search_structured                                      None
#
#                                   retrieved_contexts  \
# 0  [Apollo 11 - NASA, Apollo 11 Mission Overview ...
# 1                                                 []
#
#                                             response  \
# 0  {'verdict': 'SUPPORTED', 'summary': 'The Moon ...
# 1  {'verdict': 'INSUFFICIENT_EVIDENCE', 'summary'...
#
#                                            citations  \
# 0  [{'title': 'Apollo 11 - NASA', 'source': 'nasa...
# 1                                                 []
#
#                                  reference_answer reference_verdict    topic  \
# 0  Apollo 11 landed on the Moon on July 20, 1969.         SUPPORTED  history
# 1  Apollo 11 landed on the Moon on July 20, 1969.         SUPPORTED  history
#
#   freshness_bucket  latency_ms   status      error_type  cost_estimate  \
# 0        evergreen       12597  success            None          0.456
# 1        evergreen           0    error  BenchmarkError            NaN
#
#    cost_estimate_low  cost_estimate_high  \
# 0              0.032                0.88
# 1                NaN                 NaN
#
#                                 cost_estimate_method
# 0  Tavily Research mini uses published pay-as-you...
# 1                                               None

# %%
if raw.empty:
    raise ValueError('No artifacts found under eval/results/live')

df = raw.copy()
df['claim_text'] = df['claim'].apply(lambda value: value.get('text', ''))
df['reference_verdict'] = df['reference_verdict'].fillna('')
df['response_verdict'] = df['response'].apply(lambda value: (value or {}).get('verdict', ''))
df['response_explanation'] = df['response'].apply(lambda value: (value or {}).get('explanation', ''))
df['response_confidence'] = df['response'].apply(lambda value: (value or {}).get('confidence', np.nan))
df['latency_ms'] = pd.to_numeric(df['latency_ms'], errors='coerce').fillna(0)
df['cost_estimate'] = pd.to_numeric(df['cost_estimate'], errors='coerce').fillna(0)
df['retrieved_contexts'] = df['retrieved_contexts'].apply(lambda value: value if isinstance(value, list) else [])
df['citations'] = df['citations'].apply(lambda value: value if isinstance(value, list) else [])
df['citation_count'] = df['citations'].apply(len)
df['source_count'] = df['citations'].apply(lambda items: len({item.get('url', '') for item in items if isinstance(item, dict)}))
df['status'] = df['status'].fillna('success')

ragas_path = SUMMARY_DIR / 'ragas_scores.csv'
ragas_scores = pd.read_csv(ragas_path) if ragas_path.exists() else pd.DataFrame()
provider_summary = (
    df.groupby(['provider', 'provider_mode'], dropna=False)
      .agg(
          runs=('id', 'count'),
          success_rate=('status', lambda values: (values == 'success').mean()),
          mean_latency_ms=('latency_ms', 'mean'),
          mean_cost=('cost_estimate', 'mean'),
          mean_citations=('citation_count', 'mean'),
          verdict_accuracy=('response_verdict', lambda values: (values.reset_index(drop=True) == df.loc[values.index, 'reference_verdict'].reset_index(drop=True)).mean())
      )
      .reset_index()
)
provider_summary.to_csv(SUMMARY_DIR / 'provider_summary_from_notebook.csv', index=False)
provider_summary
# Out:
#     provider                provider_mode  runs  success_rate  \
# 0      brave         brave_answers_native     5         0.000
# 1      brave     brave_context_plus_judge     6         1.000
# 2        exa           exa_research_async     7         0.000
# 3        exa        exa_search_structured     7         0.000
# 4  firecrawl  firecrawl_search_plus_judge     6         1.000
# 5   parallel            parallel_task_run     8         0.375
# 6     tavily              tavily_research     6         1.000
#
#    mean_latency_ms  mean_cost  mean_citations  verdict_accuracy
# 0         0.000000   0.000000        0.000000          0.200000
# 1      4017.000000   0.000856        6.666667          0.666667
# 2         0.000000   0.000000        0.000000          0.142857
# 3         0.000000   0.000000        0.000000          0.142857
# 4     26029.833333   0.005854        0.000000          0.833333
# 5     42573.250000   0.001250        2.625000          0.500000
# 6     15833.333333   0.076000        4.500000          0.500000

# %% [markdown]
# ## Dataset Summary

# %%
display(df[['provider', 'provider_mode', 'status', 'latency_ms', 'citation_count', 'source_count']].head(10))
display(provider_summary)
# Out:
#     provider                provider_mode   status  latency_ms  \
# 0     tavily              tavily_research  success       12597
# 1        exa        exa_search_structured    error           0
# 2        exa           exa_research_async    error           0
# 3      brave     brave_context_plus_judge  success        4497
# 4  firecrawl  firecrawl_search_plus_judge  success       66521
# 5   parallel            parallel_task_run  success      139720
# 6     tavily              tavily_research  success       13310
# 7        exa        exa_search_structured    error           0
# 8        exa           exa_research_async    error           0
# 9      brave     brave_context_plus_judge  success        4434
#
#    citation_count  source_count
# 0               4             4
# 1               0             0
# 2               0             0
# 3               7             7
# 4               0             0
# 5               7             7
# 6               5             5
# 7               0             0
# 8               0             0
# 9               7             7
#     provider                provider_mode  runs  success_rate  \
# 0      brave         brave_answers_native     5         0.000
# 1      brave     brave_context_plus_judge     6         1.000
# 2        exa           exa_research_async     7         0.000
# 3        exa        exa_search_structured     7         0.000
# 4  firecrawl  firecrawl_search_plus_judge     6         1.000
# 5   parallel            parallel_task_run     8         0.375
# 6     tavily              tavily_research     6         1.000
#
#    mean_latency_ms  mean_cost  mean_citations  verdict_accuracy
# 0         0.000000   0.000000        0.000000          0.200000
# 1      4017.000000   0.000856        6.666667          0.666667
# 2         0.000000   0.000000        0.000000          0.142857
# 3         0.000000   0.000000        0.000000          0.142857
# 4     26029.833333   0.005854        0.000000          0.833333
# 5     42573.250000   0.001250        2.625000          0.500000
# 6     15833.333333   0.076000        4.500000          0.500000

# %% [markdown]
# ## Coverage And Failure Rate

# %%
coverage = df.groupby(['provider', 'status']).size().reset_index(name='count')
plt.figure(figsize=(12, 6))
sns.barplot(data=coverage, x='provider', y='count', hue='status')
plt.title('Provider Coverage And Outcome Counts')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Latency Distribution

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='provider', y='latency_ms')
plt.title('Latency Distribution By Provider')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Cost Estimate Comparison

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=provider_summary, x='provider', y='mean_cost')
plt.title('Mean Cost Estimate By Provider')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ragas Metrics

# %%
if ragas_scores.empty:
    print('No ragas_scores.csv found. Run eval/src/evaluate_results.py --run-ragas to populate it.')
else:
    ragas_numeric = ragas_scores.select_dtypes(include=['number']).copy()
    ragas_numeric['provider'] = ragas_scores['provider']
    ragas_means = ragas_numeric.groupby('provider').mean(numeric_only=True).reset_index()
    melted = ragas_means.melt(id_vars='provider', var_name='metric', value_name='score')
    plt.figure(figsize=(14, 6))
    sns.barplot(data=melted, x='provider', y='score', hue='metric')
    plt.title('Mean Ragas Metrics By Provider')
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(14, 6))
    ragas_long = ragas_scores.melt(id_vars=['provider', 'provider_mode', 'artifact_id'], var_name='metric', value_name='score')
    ragas_long = ragas_long[ragas_long['metric'].isin(['context_precision', 'faithfulness', 'response_relevancy'])]
    sns.boxplot(data=ragas_long, x='metric', y='score', hue='provider')
    plt.title('Ragas Metric Spread')
    plt.tight_layout()
    plt.show()
# Out:
# No ragas_scores.csv found. Run eval/src/evaluate_results.py --run-ragas to populate it.

# %% [markdown]
# ## Verdict Confusion Matrix

# %%
confusion = pd.crosstab(df['reference_verdict'], df['response_verdict'])
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues')
plt.title('Verdict Confusion Matrix')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Latency vs Faithfulness

# %%
if ragas_scores.empty or 'faithfulness' not in ragas_scores.columns:
    print('Faithfulness scores are not available yet.')
else:
    merged = df.merge(ragas_scores[['artifact_id', 'faithfulness']], left_on='id', right_on='artifact_id', how='left')
    plt.figure(figsize=(12, 6))
    sns.scatterplot(data=merged, x='latency_ms', y='faithfulness', hue='provider', s=120)
    plt.title('Latency vs Faithfulness')
    plt.tight_layout()
    plt.show()
# Out:
# Faithfulness scores are not available yet.

# %% [markdown]
# ## Citation Volume

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='citation_count', hue='provider', multiple='stack', discrete=True)
plt.title('Citation Count Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Worst Samples

# %%
worst = df.sort_values(['status', 'latency_ms'], ascending=[True, False])[['id', 'provider', 'provider_mode', 'status', 'response_verdict', 'reference_verdict', 'latency_ms', 'claim_text', 'response_explanation']]
display(worst.head(10))
# Out:
#                                                    id  provider  \
# 1   benchmark_20260502T184021Z_claim_moon_01_exa_e...       exa
# 2   benchmark_20260502T184021Z_claim_moon_01_exa_e...       exa
# 7   benchmark_20260502T171310Z_claim_moon_01_exa_e...       exa
# 8   benchmark_20260502T171310Z_claim_moon_01_exa_e...       exa
# 10  benchmark_20260502T171310Z_claim_moon_01_brave...     brave
# 12  benchmark_20260502T171310Z_claim_moon_01_paral...  parallel
# 14  benchmark_20260502T171310Z_claim_pluto_01_exa_...       exa
# 15  benchmark_20260502T171310Z_claim_pluto_01_exa_...       exa
# 17  benchmark_20260502T171310Z_claim_pluto_01_brav...     brave
# 19  benchmark_20260502T171310Z_claim_pluto_01_para...  parallel
#
#             provider_mode status       response_verdict reference_verdict  \
# 1   exa_search_structured  error  INSUFFICIENT_EVIDENCE         SUPPORTED
# 2      exa_research_async  error  INSUFFICIENT_EVIDENCE         SUPPORTED
# 7   exa_search_structured  error  INSUFFICIENT_EVIDENCE         SUPPORTED
# 8      exa_research_async  error  INSUFFICIENT_EVIDENCE         SUPPORTED
# 10   brave_answers_native  error  INSUFFICIENT_EVIDENCE         SUPPORTED
# 12      parallel_task_run  error  INSUFFICIENT_EVIDENCE         SUPPORTED
# 14  exa_search_structured  error  INSUFFICIENT_EVIDENCE             FALSE
# 15     exa_research_async  error  INSUFFICIENT_EVIDENCE             FALSE
# 17   brave_answers_native  error  INSUFFICIENT_EVIDENCE             FALSE
# 19      parallel_task_run  error  INSUFFICIENT_EVIDENCE             FALSE
#
#     latency_ms                                   claim_text  \
# 1            0           The Moon landing occurred in 1969.
# 2            0           The Moon landing occurred in 1969.
# 7            0           The Moon landing occurred in 1969.
# 8            0           The Moon landing occurred in 1969.
# 10           0           The Moon landing occurred in 1969.
# 12           0           The Moon landing occurred in 1969.
# 14           0  Pluto is officially classified as a planet.
# 15           0  Pluto is officially classified as a planet.
# 17           0  Pluto is officially classified as a planet.
# 19           0  Pluto is officially classified as a planet.
#
#                                  response_explanation
# 1   [400] Exa search failed — {"requestId":"2f8ad1...
# 2   [400] Exa async research create failed — {"sta...
# 7          [403] Exa search failed — error code: 1010
# 8   [403] Exa async research create failed — error...
# 10  [400] Brave Answers request failed — {"type":"...
# 12  [422] Parallel task create failed — {"type":"e...
# 14         [403] Exa search failed — error code: 1010
# 15  [403] Exa async research create failed — error...
# 17  [400] Brave Answers request failed — {"type":"...
# 19  [422] Parallel task create failed — {"type":"e...
